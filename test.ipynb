# %%
import json
with open("./runs/tabm/map_run_key_to_num.json", "r") as f:
    m = json.load(f)
m
# Out:
# {'test_hash': 'test_id'}

# %%
import json
with open("/home/nuwaisir/Corridor/Contests/Shell_ai_2025/runs/tabm_cv/cv_run_142/params.json", "r") as f:
    params = json.load(f)

# %%
params
# Out:
# {'embedding_type': 'PeriodicEmbeddings',
#  'n_bins': 57,
#  'd_embedding': 16,
#  'n_blocks': 1,
#  'd_block': 992,
#  'arch_type': 'tabm-mini',
#  'lr': 0.000947937977119,
#  'weight_decay': 0.0003956466296072,
#  'share_training_batches': 'F',
#  'Target': 'BlendProperty2',
#  'Score': 97.66661145450882,
#  'k': 32,
#  'score': 96.95024737545988,
#  'target_col_name': 'BlendProperty2',
#  'seed': 45,
#  'n_splits': 5}

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import QuantileTransformer
import matplotlib.pyplot as plt

df_train = pd.read_csv('./dataset/train.csv')

qt = QuantileTransformer(n_quantiles=max(min(df_train.shape[0] // 30, 1000), 10), random_state=0, output_distribution='normal')
df_train_qt = qt.fit_transform(df_train)

# %%
df_train['Component5_Property7'].hist(bins=100)
# Out:
# <Axes: >

# %%
df = pd.DataFrame(df_train_qt, columns=df_train.columns)
df['Component5_Property7'].hist(bins=100)
# Out:
# <Axes: >

# %%
plt.hist(df_train_qt[:, 7], bins=100)
plt.show()

# %%
plt.hist(df_train.values[:, 6], bins=100)
plt.show()

# %%
X_train_qt = np.load('./dataset/train_qt.npy')
plt.hist(X_train_qt[:, 7], bins=100)
plt.show()
